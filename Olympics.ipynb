# %%
import pandas as pd

# %%
df = pd.read_csv("summer.csv")

# %%
#All the logics are written in readme file in github repository
# Out:
#        Year       City      Sport           Discipline               Athlete  \
# 241    1900      Paris  Athletics            Athletics     PRITCHARD, Norman
# 244    1900      Paris  Athletics            Athletics     PRITCHARD, Norman
# 5512   1928  Amsterdam     Hockey               Hockey  ALLEN, Richard James
# 5513   1928  Amsterdam     Hockey               Hockey           CHAND, Dyan
# 5514   1928  Amsterdam     Hockey               Hockey   GATELEY, Maurice A.
# ...     ...        ...        ...                  ...                   ...
# 29879  2012     London     Boxing               Boxing             KOM, Mary
# 30841  2012     London   Shooting             Shooting         NARANG, Gagan
# 30849  2012     London   Shooting             Shooting          KUMAR, Vijay
# 31111  2012     London  Wrestling  Wrestling Freestyle       DUTT, Yogeshwar
# 31118  2012     London  Wrestling  Wrestling Freestyle         KUMAR, Sushil
#
# ...

# %%
#In how many cities Summer Olympics is held so far


print("The Olympics have been held in the following ",len(df["City"].unique()),"cities-")

for city in df["City"].unique():
    print(city)
# Out:
# The Olympics have been held in the following  22 cities-
# Athens
# Paris
# St Louis
# London
# Stockholm
# Antwerp
# Amsterdam
# Los Angeles
# Berlin
# Helsinki
# Melbourne / Stockholm
# Rome
# Tokyo
# Mexico
# Munich
# Montreal
# Moscow
# Seoul
# Barcelona
# Atlanta
# Sydney
# Beijing

# %%
#Which sport is having most number of Gold Medals so far

gold=[]

for i in df["Sport"].unique():
    count=0
    df2=(df[df["Sport"]==i])
    for medal in df2["Medal"]:
        if(medal=="Gold"):
            count += 1
    gold.append([i,count])

gold = pd.DataFrame(gold, columns=["Sport","Gold Medals"])
gold=gold.sort_values(by="Gold Medals", ascending = False).head()

print("The sports with most number of gold medals are:")
gold.plot(x="Sport",y="Gold Medals",kind="bar",figsize=(5,10))
gold
# Out:
# The sports with most number of gold medals are:
#          Sport  Gold Medals
# 0     Aquatics         1421
# 1    Athletics         1215
# 17      Rowing          890
# 4   Gymnastics          820
# 3      Fencing          552

# %%
#Which sport is having most number of medals so far

tot_medals=[]

for sport in df["Sport"].unique():
    count=len(df[df["Sport"]== sport])
    tot_medals.append([sport,count])

tot_medals= pd.DataFrame(tot_medals, columns=["Sport","Medals"])
tot_medals= tot_medals.sort_values(by="Medals", ascending = False).head()

print("The sports with most number of medals are:")
tot_medals.plot(x="Sport",y="Medals",kind="bar",figsize=(5,15))
tot_medals
# Out:
# The sports with most number of medals are:
#          Sport  Medals
# 0     Aquatics    4170
# 1    Athletics    3638
# 17      Rowing    2667
# 4   Gymnastics    2307
# 3      Fencing    1613

# %%
#Which player has won most number of medals

ply_medals=[]

for player in df["Athlete"].unique():
    count=len(df[df["Athlete"]== player])
    ply_medals.append([player,count])

ply_medals= pd.DataFrame(ply_medals, columns=["Athlete","Medals"])
ply_medals= ply_medals.sort_values(by="Medals", ascending = False).head()

print("The Athletes with most number of medals are:")
ply_medals.plot(x="Athlete",y="Medals",kind="bar",figsize=(5,5))
ply_medals
# Out:
# The Athlete with most number of medals are:
#                     Athlete  Medals
# 18640       PHELPS, Michael      22
# 7197       LATYNINA, Larisa      18
# 9948     ANDRIANOV, Nikolay      15
# 6591           ONO, Takashi      13
# 5103   MANGIAROTTI, Edoardo      13

# %%
#Which player has won most number Gold Medals of medals

ply_gold=[]

for i in df["Athlete"].unique():
    count=0
    df2=(df[df["Athlete"]==i])
    for medal in df2["Medal"]:
        if(medal=="Gold"):
            count += 1
    ply_gold.append([i,count])

ply_gold = pd.DataFrame(ply_gold, columns=["Athlete","Gold Medals"])
ply_gold=ply_gold.sort_values(by="Gold Medals", ascending = False).head()

print("The athlete with most number of gold medals are:")
ply_gold.plot(x="Athlete",y="Gold Medals",kind="bar")
ply_gold
# Out:
# The athlete with most number of gold medals are:
#                 Athlete  Gold Medals
# 18640   PHELPS, Michael           18
# 12468       LEWIS, Carl            9
# 8811        SPITZ, Mark            9
# 2262       NURMI, Paavo            9
# 7197   LATYNINA, Larisa            9

# %%
#In which year India won first Gold Medal in Summer Olympics


for i in df["Country"].unique():
    if i == "IND":
        df2=df[df["Country"]=="IND"]
        for medal in df2["Medal"]:
            if medal=="Gold":
                df3 = df2[df2["Medal"]=="Gold"]
                
df3=df3.head(1)
print("India won its first gold in")
df3
# Out:
# India won its first gold in
#       Year       City   Sport Discipline               Athlete Country Gender  \
# 5512  1928  Amsterdam  Hockey     Hockey  ALLEN, Richard James     IND    Men
#
#        Event Medal
# 5512  Hockey  Gold

# %%
#Which event is most popular in terms on number of players

events=[]

for i in df["Event"].unique():
    df2=df[df["Event"]==i]
    events.append([i,len(df2["Athlete"].unique())])
    
events = pd.DataFrame(events, columns=["Event","Athletes"])
events=events.sort_values(by="Athletes", ascending = False).head()

events.plot(x="Event",y="Athletes",kind="bar")
events
# Out:
#                         Event  Athletes
# 80                   Football      1357
# 176                    Hockey      1154
# 138          Team Competition       975
# 83   Eight With Coxswain (8+)       828
# 327                Basketball       814

# %%
#Which sport is having most female Gold Medalists

female=[]

for i in df["Gender"].unique():
    if i == "Women":
        df2=df[df["Gender"]=="Women"]
        for medal in df2["Medal"]:
            if medal=="Gold":
                df3 = df2[df2["Medal"]=="Gold"]
                
for j in df3["Sport"].unique():
    count=len(df3[df3["Sport"]== j])
    female.append([j,count])
    
female = pd.DataFrame(female, columns=["Sport","Female gold Medalist"])
female = female.sort_values(by="Female gold Medalist", ascending = False).head()

female.plot(x="Sport",y="Female gold Medalist",kind="bar")
female
# Out:
#          Sport  Female gold Medalist
# 4     Aquatics                   589
# 7    Athletics                   389
# 8   Gymnastics                   268
# 14      Rowing                   217
# 11  Volleyball                   166

# %%
# Out:
#        Year      City          Sport           Discipline  \
# 417    1900     Paris           Golf                 Golf
# 641    1900     Paris         Tennis               Tennis
# 649    1900     Paris         Tennis               Tennis
# 710    1904  St Louis        Archery              Archery
# 713    1904  St Louis        Archery              Archery
# ...     ...       ...            ...                  ...
# 31081  2012    London  Weightlifting        Weightlifting
# 31097  2012    London      Wrestling  Wrestling Freestyle
# 31105  2012    London      Wrestling  Wrestling Freestyle
# 31113  2012    London      Wrestling  Wrestling Freestyle
# 31121  2012    London      Wrestling  Wrestling Freestyle
#
#                      Athlete Country Gender  \
# 417    ABBOTT, Margaret Ives     USA  Women
# 641        COOPER, Charlotte     GBR  Women
# 649        COOPER, Charlotte     GBR  Women
# 710    HOWELL, Matilda Scott     USA  Women
# ...
